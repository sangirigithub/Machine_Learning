# %% [markdown]
# Before onboarding a new customer, we need to check whether customer already exists within the system.
# If customer details exactly matches in all attributes, it is easy to find out whether existing customer or not.
# Most of the times, customer attributes may not be exactly same even though it is same customer.
# Implement a google like search i.e., fuzzy logic search utility for CRM,
# to search existing customer based on multiple criteria Name, Address etc.
#
# a. Advanced search algorithm (Phonetic algorithms etc.)
#
# b. Integration - real time data search from enterprise application to display results.
#
# c. Performance of algorithm

# %% [markdown]
# # My References include GeeksforGeeks.com & Medium.com

# %% [markdown]
# #### 1. Import Required Python Libraries including Phonetic & FuzzyWuzzy

# %%
pip install soundex
# Out:
# Requirement already satisfied: soundex in /usr/local/lib/python3.10/dist-packages (1.1.3)
# Requirement already satisfied: silpa-common>=0.3 in /usr/local/lib/python3.10/dist-packages (from soundex) (0.3)

# %%
pip install fuzzywuzzy
# Out:
# Requirement already satisfied: fuzzywuzzy in /usr/local/lib/python3.10/dist-packages (0.18.0)

# %%
import pandas as pd
from fuzzywuzzy import fuzz, process
print('Libraries Imported!')
# Out:
# Libraries Imported!
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #### 2. Read Dataset & Prepare List of Customer's Full Names

# %%
### ###############################################################################
# 1 a. Read Customer Database for information on Existing Customers
cust_info_raw = pd.read_csv(r'/content/drive/MyDrive/CRM_Customer_Search_Algorithm/customer_info.csv')
# ['CustID', 'First Name', 'Middle Name', 'Last Name', 'Email', 'Phone', 'Address Line 1', 'Address Line 2', 'City', 'State', 'PinCode']

# cust_info = cust_info_raw[['first_name', 'last_name', 'email', 'phone', 'address', 'gender']]
cust_info = cust_info_raw[['CustID', 'first_name', 'last_name', 'address']]

print('**************************************************************************')
print(cust_info.shape, cust_info.columns)

### ###############################################################################
# 1 b. Derive Customer's Full Name & Prepare List of Customer's Full Name
cust_info['full_name']  = cust_info.loc[:, 'first_name'] + ' ' + cust_info.loc[:, 'last_name']
list_fullName = cust_info['full_name'].to_list()
print('*************************************************************************')
print('list_fullName: ', len(list_fullName), '\n', list_fullName)

### ###############################################################################
# 1 c. Derive Customer's Full Address & Prepare List of Customer's Full Address
list_fullAddr = cust_info['address'].to_list()
print('*************************************************************************')
print('list_fullAddr: ', len(list_fullAddr), '\n', list_fullAddr)

### ###############################################################################
# 1 d. Dimensions of Customer's Dataset
print('**************************************************************************')
print(cust_info.shape, cust_info.columns)
print('**************************************************************************')
cust_info.head(6)
# Out:
# **************************************************************************
# (1000, 4) Index(['CustID', 'first_name', 'last_name', 'address'], dtype='object')
# *************************************************************************
# list_fullName:  1000
#  ['Joseph Rice', 'Gary Moore', 'John Walker', 'Eric Carter', 'William Jackson', 'Nicole Jones', 'David Davis', 'Jason Montgomery', 'Kent Weaver', 'Darrell Dillon', 'Jacqueline Wang', 'Jodi Gonzalez', 'Omar Martin', 'Nicole Lara', 'Jason Brown', 'David Benson', 'Kimberly Mora', 'Erik Macias', 'James Johnson', 'Derek Peterson', 'Diane Henson', 'Cody Lyons', 'Margaret Hardy', 'Arthur Hayes', 'Raymond Taylor', 'Tina Moore', 'Kylie White', 'Jonathan Manning', 'Angela Bryant', 'Michael Mann', 'Craig Myers', 'Tiffany Carter', 'Erica Owens', 'Patricia Parker', 'Brian Palmer', 'Melissa Smith', 'Connor Adams', 'Michael Williams', 'Ruth Smith', 'Jonathan Middleton', 'Francis Velez', 'Matthew Velez', 'Kim Shaw', 'Gary Jones', 'Nicholas Clayton', 'Anthony Chavez', 'Carolyn Green', 'Janice Roman', 'Erin Taylor', 'Charles Garcia', 'John Huber', 'Haley Martinez', 'Adam Holmes', 'Patricia Jones', 'Christy Rodriguez', 'Jose Poole', 'Lacey Mercado', 'Danielle Garcia', 'Amanda Cohen', 'Jeremy Rodriguez', 'Jade Wall', 'Janice Garcia', 'Sarah Greer', 'Sandra Golden', 'David Fritz', 'Hannah Wu', 'Guy Bennett', 'Regina Wong', 'Desiree Webster', 'Juan Cruz', 'Michelle Edwards', 'Alexander Griffin', 'Laura House', 'Brittany Hanna', 'Allen Wright', 'Ricky Phillips', 'Adrian Cross', 'Thomas Wood', 'Jillian Massey', 'Kevin Watkins', 'Allison Sweeney', 'Joseph Hernandez', 'Steven Little', 'John Bennett', 'Michele Maxwell', 'Emily Thomas', 'Mark Rogers', 'John Cruz', 'David Yoder', 'James Reynolds', 'Stephanie Hicks', 'Paul Brown', 'Alexandra Morales', 'Krystal Carroll', 'Alyssa Walker', 'Eric Harvey', 'Debbie Rogers', 'Steve Braun', 'Ryan Rojas', 'Andrew Levine', 'Brian Olson', 'Jessica Welch', 'Stephanie Faulkner', 'Dawn Johnson', 'Monique Wright', 'Veronica Stein', 'Breanna Santos', 'Jeremy Lee', 'Robert Moore', 'Tiffany Pearson', 'Audrey Richardson', 'Maureen Bryant', 'Derrick Roberts', 'Jeffrey Sullivan', 'Amy Harris', 'Rhonda Flores', 'Steven Black', 'Robert Shepherd', 'Robin Snyder', 'Elijah Cook', 'Dennis Hill', 'Charles Nunez', 'Philip Robinson', 'Rachel Larson', 'Stephen Sharp', 'Aimee Jacobs', 'Brittany Miller', 'Sabrina Mclaughlin', 'Amber Banks', 'Casey Todd', 'Miranda Williams', 'Alexander Williams', 'Jesus Higgins', 'James Keith', 'Shawn Johnson', 'Natalie Page', 'Zachary Fowler', 'Brian Bowman', 'Ryan Martin', 'Jennifer Silva', 'Joseph Sparks', 'Mary Bishop', 'Stacey Welch', 'Brett Burns', 'Michael Case', 'Terry Bailey', 'Christopher Mcdonald', 'Andres Becker', 'Chase Mcdaniel', 'Sherry Parsons', 'Javier Jones', 'Jill Kane', 'Janet Valdez', 'Karen Ford', 'Jamie Johnson', 'Jessica Marshall', 'Sharon Warner', 'Zachary Williams', 'Brooke Durham', 'Ryan Murray', 'Gabrielle Smith', 'Nicole Bennett', 'Heather Ali', 'Sandra Mcmahon', 'Bailey Mercado', 'Morgan Cooper', 'Matthew Stokes', 'Timothy Mullins', 'Kenneth Rubio', 'Mary Zamora', 'Larry Cole', 'Jeffrey Diaz', 'Joseph Brown', 'Emily Jones', 'Tara Davis', 'Tiffany Bowers', 'Linda Craig', 'Christine Smith', 'Matthew Williams', 'Brenda Lewis', 'Adrian West', 'Amy Scott', 'April Beck', 'Anthony Nicholson', 'Shari Garcia', 'Xavier Miles', 'Rachael Gilbert', 'Michele Rogers', 'Derek Dixon', 'Grace Hartman', 'Joseph Miller', 'David Arnold', 'Yesenia White', 'Nancy Miller', 'Christopher Doyle', 'Taylor Reed', 'Katherine Ferguson', 'Robert Bryan', 'Zachary Kane', 'Rebecca Robinson', 'Bethany Anderson', 'Mary Williams', 'Carlos Wallace', 'Rhonda Matthews', 'Donald Barker', 'Courtney Lopez', 'Chelsea Moyer', 'Brittany Golden', 'Russell Berry', 'Joshua Jackson', 'Alicia Thompson', 'Clifford Gray', 'Gloria Miller', 'Nicole Mcintyre', 'Vincent Kline', 'Amber Hunter', 'Shelby Gomez', 'Thomas Mclaughlin', 'Nathan Graham', 'Thomas Guzman', 'Sarah Gilbert', 'Jeremy Andrews', 'Megan Morris', 'Zachary Davis', 'Michael Phelps', 'Christopher Robinson', 'Aaron Mckee', 'Andrea Velasquez', 'Philip Newton', 'Kathleen Palmer', 'Eric Levine', 'Michael Lopez', 'Samantha Smith', 'Diane Tanner', 'Melissa Gaines', 'Alicia Je ...
# *************************************************************************
# list_fullAddr:  1000
#  ['91773 Miller Shoal\r\nDiaztown, FL 38841', '6450 John Lodge\r\nTerriton, KY 95945', '27265 Murray Island\r\nKevinfort, PA 63231', 'USNS Knight\r\nFPO AA 76532', '170 Jackson Loaf\r\nKristenland, AS 48876', '14354 Baker Harbor Apt. 017\r\nEricville, HI 11192', '021 Katherine Mall\r\nJameston, DC 24685', '14657 Scott Loop Apt. 735\r\nPort Ashley, NH 34470', '6644 Mitchell Burg\r\nVictorhaven, KS 66356', 'PSC 7267, Box 9911\r\nAPO AE 49343', '16963 Stewart Curve Suite 279\r\nSouth Cameron, ND 25136', '378 Johnson Oval\r\nSouth Stacie, RI 76332', 'Unit 9103 Box 4771\r\nDPO AA 16592', '9822 Lisa Courts\r\nJohnhaven, IL 80438', '7310 Romero Summit\r\nEast Scotttown, DC 53183', '444 Derek Summit\r\nLisaborough, WA 20685', '7679 Perry Square\r\nWest Amybury, RI 15144', '568 Christopher Tunnel\r\nToddburgh, DE 86966', '19870 Sean Parkway\r\nNorth Jamesfurt, NC 28950', '70830 Jonathan Pine\r\nWilcoxburgh, MI 38265', '86382 Baker Ports Apt. 074\r\nCookfurt, NM 54313', '60971 Carrillo Square Suite 141\r\nNew Kimberlybury, AS 02128', '2900 Sandra Villages Apt. 985\r\nPhillipsstad, NH 19830', '353 Elizabeth Forest\r\nDeannachester, NM 66952', '07867 John Mills Apt. 985\r\nTinaville, ID 59142', '50984 Shelly Pass\r\nPort Nicholas, SC 48629', '5004 Christine Falls Suite 217\r\nJasonburgh, NJ 75688', '1501 Gregory Glens Suite 940\r\nStephensstad, GU 55206', '01454 Christopher Turnpike\r\nNorth Ryanstad, MI 36226', '93144 Martinez Turnpike\r\nEast Maryhaven, MD 06798', '248 Koch Harbor\r\nJonathanhaven, AL 29645', 'PSC 9395, Box 0886\r\nAPO AE 29897', 'PSC 3509, Box 5359\r\nAPO AP 47664', '69076 James Lights\r\nJeremyton, ID 40460', 'USNV Smith\r\nFPO AP 16161', '24619 David Drive\r\nNew Davidmouth, TX 88651', '997 Jessica Locks\r\nJosephshire, NC 76033', '72249 Maria Summit Suite 055\r\nEast Danielton, MP 13831', 'USNV Woods\r\nFPO AA 79528', '6657 Sabrina Point Suite 915\r\nNew Robert, MD 65031', '060 Christopher Extensions\r\nYoungmouth, AR 10160', '206 Larry Divide Apt. 484\r\nNorth Justin, NH 22202', 'Unit 9987 Box 4002\r\nDPO AA 15069', '5624 John Corner\r\nVictorstad, IA 25172', '52017 Miller Summit\r\nBenjaminshire, AZ 90897', 'USCGC Cervantes\r\nFPO AP 51042', '16623 Jordan Estate Suite 664\r\nEast Stephanie, CT 22452', '5953 Gill Centers\r\nMasontown, MI 39024', '48599 Russell Wall\r\nGreeneburgh, MS 66862', '13369 Porter Plains Apt. 971\r\nNorth Markfurt, AZ 67818', 'Unit 3189 Box 8193\r\nDPO AA 08720', '5431 Christopher Dale\r\nJoshuahaven, CT 52230', '3854 Harris Lakes\r\nPort Kaylashire, FM 70720', '098 Shelly Dale Apt. 244\r\nDelgadoshire, SD 26738', '859 Colin Oval\r\nNew Michael, MT 06634', '8382 Leslie Burgs\r\nWest Robert, NJ 30160', '04225 Lee Manor\r\nCastroville, HI 72528', '0791 Tiffany Well\r\nWest Matthew, RI 08141', '37967 Kathryn Coves\r\nSouth Stevenberg, AS 79859', '287 Guerrero Roads Suite 079\r\nOchoatown, CT 50932', '762 Anita Lake Suite 890\r\nJosefurt, OH 77880', '7536 Yang Court\r\nNew Jennifermouth, LA 34189', '998 Burns Divide\r\nCarterhaven, VI 92800', '239 Mitchell Plaza\r\nAllenborough, MS 09082', '8627 Brian Spur Apt. 855\r\nGonzalezfort, KS 26516', '63827 Justin Estate\r\nLake Susanbury, TN 74666', '21120 Anderson Isle\r\nNorth Michaelside, CA 64898', '97722 Carter Lodge\r\nWest Mirandaburgh, WV 83151', '648 Garcia Light Apt. 666\r\nPrestonberg, AK 20231', '429 Bonnie Via Suite 513\r\nWattsburgh, OK 75680', 'USNS Kelley\r\nFPO AA 54670', '45253 Glass Divide Apt. 272\r\nLake Timothy, AZ 87119', '87635 Smith Falls Apt. 959\r\nBrownton, IN 24891', '62994 Lindsey Estate\r\nLake Christine, VA 10667', 'USNV Gonzalez\r\nFPO AE 23095', '2598 Watson Points\r\nJohnsonstad, RI 13310', '545 Manning Tunnel\r\nMcintoshland, KS 74967', '0943 Ayala Garden\r\nEast Ann, UT 95055', 'PSC 9428, Box 6762\r\nAPO AA 54022', '8175 Hicks Stravenue\r\nMichaeltown, FM 63439', '850 Smith Squares Suite 535\r\nNorth Kimberlyborough, GA 18207', '7913 Watson Station Apt. 861\r\nMichaelchester, WY 29884', '5268 Billy Glen\r\nLake Kat ...
# **************************************************************************
# (1000, 5) Index(['CustID', 'first_name', 'last_name', 'address', 'full_name'], dtype='object')
# **************************************************************************
# <ipython-input-5-985dbbc744b2>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cust_info['full_name']  = cust_info.loc[:, 'first_name'] + ' ' + cust_info.loc[:, 'last_name']
#    CustID first_name last_name  \
# 0   10010     Joseph      Rice
# 1   10011       Gary     Moore
# 2   10012       John    Walker
# 3   10013       Eric    Carter
# 4   10014    William   Jackson
# 5   10015     Nicole     Jones
#
#                                              address        full_name
# 0           91773 Miller Shoal\r\nDiaztown, FL 38841      Joseph Rice
# 1              6450 John Lodge\r\nTerriton, KY 95945       Gary Moore
# 2         27265 Murray Island\r\nKevinfort, PA 63231      John Walker
# 3                        USNS Knight\r\nFPO AA 76532      Eric Carter
# 4          170 Jackson Loaf\r\nKristenland, AS 48876  William Jackson
# 5  14354 Baker Harbor Apt. 017\r\nEricville, HI 1...     Nicole Jones

# %% [markdown]
# #### 3. Assign Name & Address Values for the Customer to be searched

# %%
### ###############################################################################
# 1 c. Assign Customer's Full Name that needs to be Searched and Matched against Existing Customers
# search_firstname = input('Enter First Name of the Customer you want to Search: ')
# search_fullName = 'Caroline Green'
search_fullName = 'sandhya yenugula'
print('**************************************************************************')
print("Name to Search: '", search_fullName, "'")

search_fullAddress = r'16623 Jordan Estate Suite 664 East Stephanie, CT 22452'
print('**************************************************************************')
print("Address to be searched if Name Match Found: '", search_fullAddress, "'")
print('**************************************************************************')
# Out:
# **************************************************************************
# Name to Search: ' sandhya yenugula '
# **************************************************************************
# Address to be searched if Name Match Found: ' 16623 Jordan Estate Suite 664 East Stephanie, CT 22452 '

# %% [markdown]
# #### 4. Method to Obtain 'Soundex Phonetic Hash Code'
# Call this Method passing Strings of "Customer Full Name & Address" for both the Customer Name & Address to be Searched and also Name & Address in the Dataset.
# Thi will Tokenize the string into Tokens and obtain the hash code to be compared for Matching

# %%
### ###############################################################################
# 2. a. Find if the Customer already Exists using "Soundex Phonetic Hash Code"
### Method to Generate Soundex Phonetic Hash Code
def soundex_Phonetic_HashCode(search_string):

  lst_stringHashCode = []

  for token in search_string.split():

    # print('**************************************************************************')
    # print('token === ', token)
    # print('lst_stringHashCode === ', lst_stringHashCode)
    ### Convert Token Characteres to Upper Case for Has Code Comparison
    token = token.upper()

    token_hash_code = ''

    # Retain the First Letter
    token_hash_code += token[0]

    # Create Dictionary for Letter & Soundex Phonetic Hash Code Mapping.
    # 'H', 'W', 'Y' & Vowels are mapped to '.',
    # because they do not impact phonetic distinction of a Word like Consonants

    dict_hashCode = {"BFPV": "1", "CGJKQSXZ": "2",
                    "DT": "3",
                    "L": "4", "MN": "5", "R": "6",
                    "AEIOUHWY": "."}

    # Derive Soundex Phonetic Hash Code for Characters from 2nd till Last
    for char in token[1:]:
      for key in dict_hashCode.keys():
        if char in key:
          hash_code = dict_hashCode[key]
          # print('CHAR === ', char, 'KEY === ', key, 'hash_code === ', hash_code)
          if hash_code != '.' and hash_code != token_hash_code[-1]:
            token_hash_code += hash_code

    # Trim or Pad to keep the Hash_code 7 Digits to find Matching Tokens
    token_hash_code = token_hash_code[:7].ljust(7, '0')
    # print('token_hash_code === ', token_hash_code)

    lst_stringHashCode.append(token_hash_code)
    # print('lst_stringHashCode === ', lst_stringHashCode)

  return lst_stringHashCode

# %%
# lst_stringHashCode = soundex_Phonetic_HashCode('i am learning phonetic matching')
lst_searchFullName_HashCode = soundex_Phonetic_HashCode(search_fullName)
print('lst_searchFullName_HashCode === ', lst_searchFullName_HashCode)
# Out:
# lst_searchFullName_HashCode ===  ['S530000', 'Y524000']

# %%
list_CustFullName_HashCode = []
for fullName in list_fullName:
  fullName_HashCode = soundex_Phonetic_HashCode(fullName)
  list_CustFullName_HashCode.append(fullName_HashCode)

print('list_CustFullName_HashCode === ', list_CustFullName_HashCode)
# Out:
# list_CustFullName_HashCode ===  [['J210000', 'R200000'], ['G600000', 'M600000'], ['J500000', 'W426000'], ['E620000', 'C636000'], ['W450000', 'J250000'], ['N240000', 'J520000'], ['D130000', 'D120000'], ['J250000', 'M532560'], ['K530000', 'W160000'], ['D640000', 'D450000'], ['J245000', 'W520000'], ['J300000', 'G524200'], ['O560000', 'M635000'], ['N240000', 'L600000'], ['J250000', 'B650000'], ['D130000', 'B525000'], ['K516400', 'M600000'], ['E620000', 'M200000'], ['J520000', 'J525000'], ['D620000', 'P362500'], ['D500000', 'H525000'], ['C300000', 'L520000'], ['M626300', 'H630000'], ['A636000', 'H200000'], ['R530000', 'T460000'], ['T500000', 'M600000'], ['K400000', 'W300000'], ['J535000', 'M520000'], ['A524000', 'B653000'], ['M240000', 'M500000'], ['C620000', 'M620000'], ['T150000', 'C636000'], ['E620000', 'O520000'], ['P362000', 'P626000'], ['B650000', 'P456000'], ['M420000', 'S530000'], ['C560000', 'A352000'], ['M240000', 'W452000'], ['R300000', 'S530000'], ['J535000', 'M343500'], ['F652000', 'V420000'], ['M300000', 'V420000'], ['K500000', 'S000000'], ['G600000', 'J520000'], ['N242000', 'C435000'], ['A535000', 'C120000'], ['C645000', 'G650000'], ['J520000', 'R500000'], ['E650000', 'T460000'], ['C642000', 'G620000'], ['J500000', 'H160000'], ['H400000', 'M635200'], ['A350000', 'H452000'], ['P362000', 'J520000'], ['C623000', 'R362000'], ['J200000', 'P400000'], ['L200000', 'M623000'], ['D540000', 'G620000'], ['A530000', 'C500000'], ['J650000', 'R362000'], ['J300000', 'W400000'], ['J520000', 'G620000'], ['S600000', 'G600000'], ['S536000', 'G435000'], ['D130000', 'F632000'], ['H500000', 'W000000'], ['G000000', 'B530000'], ['R250000', 'W520000'], ['D260000', 'W123600'], ['J500000', 'C620000'], ['M240000', 'E363200'], ['A425360', 'G615000'], ['L600000', 'H200000'], ['B635000', 'H500000'], ['A450000', 'W623000'], ['R200000', 'P412000'], ['A365000', 'C620000'], ['T520000', 'W300000'], ['J450000', 'M200000'], ['K150000', 'W325200'], ['A425000', 'S500000'], ['J210000', 'H653200'], ['S315000', 'L340000'], ['J500000', 'B530000'], ['M240000', 'M240000'], ['E540000', 'T520000'], ['M620000', 'R262000'], ['J500000', 'C620000'], ['D130000', 'Y360000'], ['J520000', 'R543200'], ['S315000', 'H200000'], ['P400000', 'B650000'], ['A425360', 'M642000'], ['K623400', 'C640000'], ['A420000', 'W426000'], ['E620000', 'H610000'], ['D100000', 'R262000'], ['S310000', 'B650000'], ['R500000', 'R200000'], ['A536000', 'L150000'], ['B650000', 'O425000'], ['J200000', 'W420000'], ['S315000', 'F425600'], ['D500000', 'J525000'], ['M520000', 'W623000'], ['V652000', 'S350000'], ['B650000', 'S532000'], ['J650000', 'L000000'], ['R163000', 'M600000'], ['T150000', 'P625000'], ['A360000', 'R263250'], ['M650000', 'B653000'], ['D620000', 'R163200'], ['J160000', 'S415000'], ['A500000', 'H620000'], ['R530000', 'F462000'], ['S315000', 'B420000'], ['R163000', 'S163000'], ['R150000', 'S536000'], ['E420000', 'C200000'], ['D520000', 'H400000'], ['C642000', 'N520000'], ['P410000', 'R152500'], ['R240000', 'L625000'], ['S315000', 'S610000'], ['A500000', 'J212000'], ['B635000', 'M460000'], ['S165000', 'M242450'], ['A516000', 'B520000'], ['C200000', 'T300000'], ['M653000', 'W452000'], ['A425360', 'W452000'], ['J200000', 'H252000'], ['J520000', 'K300000'], ['S500000', 'J525000'], ['N340000', 'P200000'], ['Z260000', 'F460000'], ['B650000', 'B500000'], ['R500000', 'M635000'], ['J516000', 'S410000'], ['J210000', 'S162000'], ['M600000', 'B210000'], ['S320000', 'W420000'], ['B630000', 'B652000'], ['M240000', 'C200000'], ['T600000', 'B400000'], ['C623160', 'M235430'], ['A536200', 'B260000'], ['C200000', 'M235400'], ['S600000', 'P625200'], ['J160000', 'J520000'], ['J400000', 'K500000'], ['J530000', 'V432000'], ['K650000', 'F630000'], ['J500000', 'J525000'], ['J200000', 'M624000'], ['S650000', 'W656000'], ['Z260000', 'W452000'], ['B620000', 'D650000'], ['R500000', 'M600000'], ['G164000', 'S530000'], ['N240000', 'B530000'], ['H360000', 'A400000'], ['S536000', 'M250000'], ['B400000', 'M623000'], ['M6250 ...

# %%
list_searchFullAddr_HashCode = soundex_Phonetic_HashCode(search_fullAddress)
print('searchFullAddr_HashCode === ', list_searchFullAddr_HashCode)
# Out:
# searchFullAddr_HashCode ===  ['1000000', 'J635000', 'E230000', 'S300000', '6000000', 'E230000', 'S315000', 'C300000', '2000000']

# %%
list_CustFullAddr_HashCode = []
for address in list_fullAddr:
  fullAddr_HashCode = soundex_Phonetic_HashCode(address)
  list_CustFullAddr_HashCode.append(fullAddr_HashCode)

print('list_CustFullAddr_HashCode === ', list_CustFullAddr_HashCode)
# Out:
# list_CustFullAddr_HashCode ===  [['9000000', 'M460000', 'S400000', 'D235000', 'F400000', '3000000'], ['6000000', 'J500000', 'L320000', 'T635000', 'K000000', '9000000'], ['2000000', 'M600000', 'I245300', 'K151630', 'P000000', '6000000'], ['U252000', 'K523000', 'F100000', 'A000000', '7000000'], ['1000000', 'J250000', 'L100000', 'K623545', 'A200000', '4000000'], ['1000000', 'B260000', 'H616000', 'A130000', '0000000', 'E621400', 'H000000', '1000000'], ['0000000', 'K365000', 'M400000', 'J523500', 'D200000', '2000000'], ['1000000', 'S230000', 'L100000', 'A130000', '7000000', 'P630000', 'A240000', 'N000000', '3000000'], ['6000000', 'M324000', 'B620000', 'V236150', 'K200000', '6000000'], ['P200000', '7000000', 'B200000', '9000000', 'A100000', 'A000000', '4000000'], ['1000000', 'S363000', 'C610000', 'S300000', '2000000', 'S300000', 'C565000', 'N300000', '2000000'], ['3000000', 'J525000', 'O140000', 'S300000', 'S320000', 'R000000', '7000000'], ['U530000', '9000000', 'B200000', '4000000', 'D100000', 'A000000', '1000000'], ['9000000', 'L200000', 'C632000', 'J515000', 'I400000', '8000000'], ['7000000', 'R560000', 'S530000', 'E230000', 'S235000', 'D200000', '5000000'], ['4000000', 'D620000', 'S530000', 'L216200', 'W000000', '2000000'], ['7000000', 'P600000', 'S260000', 'W230000', 'A516000', 'R000000', '1000000'], ['5000000', 'C623160', 'T540000', 'T316200', 'D000000', '8000000'], ['1000000', 'S500000', 'P620000', 'N630000', 'J521630', 'N200000', '2000000'], ['7000000', 'J535000', 'P500000', 'W421620', 'M000000', '3000000'], ['8000000', 'B260000', 'P632000', 'A130000', '0000000', 'C216300', 'N500000', '5000000'], ['6000000', 'C640000', 'S260000', 'S300000', '1000000', 'N000000', 'K516416', 'A200000', '0000000'], ['2000000', 'S536000', 'V420000', 'A130000', '9000000', 'P412300', 'N000000', '1000000'], ['3000000', 'E421300', 'F623000', 'D523600', 'N500000', '6000000'], ['0000000', 'J500000', 'M420000', 'A130000', '9000000', 'T514000', 'I300000', '5000000'], ['5000000', 'S400000', 'P200000', 'P630000', 'N242000', 'S200000', '4000000'], ['5000000', 'C623500', 'F420000', 'S300000', '2000000', 'J251620', 'N200000', '7000000'], ['1000000', 'G626000', 'G452000', 'S300000', '9000000', 'S315230', 'G000000', '5000000'], ['0000000', 'C623160', 'T651200', 'N630000', 'R523000', 'M000000', '3000000'], ['9000000', 'M635200', 'T651200', 'E230000', 'M615000', 'M300000', '0000000'], ['2000000', 'K200000', 'H616000', 'J535150', 'A400000', '2000000'], ['P200000', '9000000', 'B200000', '0000000', 'A100000', 'A000000', '2000000'], ['P200000', '3000000', 'B200000', '5000000', 'A100000', 'A100000', '4000000'], ['6000000', 'J520000', 'L232000', 'J653500', 'I300000', '4000000'], ['U251000', 'S530000', 'F100000', 'A100000', '1000000'], ['2000000', 'D130000', 'D610000', 'N000000', 'D135300', 'T200000', '8000000'], ['9000000', 'J200000', 'L200000', 'J212600', 'N200000', '7000000'], ['7000000', 'M600000', 'S530000', 'S300000', '0000000', 'E230000', 'D543500', 'M100000', '1000000'], ['U251000', 'W320000', 'F100000', 'A000000', '7000000'], ['6000000', 'S165000', 'P530000', 'S300000', '9000000', 'N000000', 'R163000', 'M300000', '6000000'], ['0000000', 'C623160', 'E235252', 'Y525300', 'A600000', '1000000'], ['2000000', 'L600000', 'D130000', 'A130000', '4000000', 'N630000', 'J235000', 'N000000', '2000000'], ['U530000', '9000000', 'B200000', '4000000', 'D100000', 'A000000', '1000000'], ['5000000', 'J500000', 'C656000', 'V236230', 'I000000', '2000000'], ['5000000', 'M460000', 'S530000', 'B525260', 'A200000', '9000000'], ['U200000', 'C615320', 'F100000', 'A100000', '5000000'], ['1000000', 'J635000', 'E230000', 'S300000', '6000000', 'E230000', 'S315000', 'C300000', '2000000'], ['5000000', 'G400000', 'C536200', 'M253500', 'M000000', '3000000'], ['4000000', 'R240000', 'W400000', 'G651620', 'M200000', '6000000'], ['1000000', 'P636000', 'P452000', 'A130000', '9000000', 'N630000', 'M621630', 'A200000', '6000000'], ['U530000', '3000000', 'B200000', '8000000', 'D100000', 'A000000', '0000 ...

# %% [markdown]
# #### 5. First Find if the New Customer's Name and also Address is Matching with Name & Address of any Customers already Exists or is a New Customer

# %%
### ###############################################################################
# Find if the Customer already Exists using Fuzz.token_set_ratio()
# Tokenizes each string and then instead of immediately comparing the sorted tokens,
# Then they are split into two groups- intersection and remainder.
# These groups are then used for string comaprision

# # Find if the Customer already Exists using Fuzz.token_sort_ratio
# # Tokenizes each String and sorts in alphabetical order, then compares both strings and returns the Similarity Score

for cust_index, custFullName_hashCode in enumerate(list_CustFullName_HashCode):
  # fuzzy_matches = process.extract(lst_searchFullName_HashCode, list_CustFullName_HashCode, scorer=fuzz.token_sort_ratio, limit=3)

  firstName_Similarity = fuzz.token_set_ratio(lst_searchFullName_HashCode[0], custFullName_hashCode[0])
  lastName_Similarity = fuzz.token_set_ratio(lst_searchFullName_HashCode[1], custFullName_hashCode[1])

  if (firstName_Similarity >= 90) and (lastName_Similarity >= 90):
    search_found_index = cust_index
    print("New Customer Name Match found in Existing Customer Names using 'fuzz.token_set_ratio'")
    print('New Customer Name === ', search_fullName, 'found at Index === ', search_found_index, cust_index)
    print('First Name & Last Name Similarity is === ', firstName_Similarity, lastName_Similarity)

  else:
    search_found_index = NULL
    print('Similarity < 90, Customer does not seem to be found in the dataset!')
    break
# Out:
# Similarity < 90, Customer does not seem to be found in the dataset!

# %% [markdown]
# #### 6. Lets also Check Customer's Address for the same Matched-Customer-Name is Similar

# %%
from zmq import NULL
# Find Address of the Matched-Customer-Name; fuzz.token_set_ratio
if search_found_index!= NULL:

  custFullAddr_hashCode = list_CustFullAddr_HashCode[search_found_index]
  str_CustFullAdrr_hashCode = ' '.join(custFullAddr_hashCode)
  print('custAddr_hashCode === ', str_CustFullAdrr_hashCode)

  str_searchFullAddr_HashCode = ' '.join(list_searchFullAddr_HashCode)
  print('str_searchFullAddr_HashCode === ', str_searchFullAddr_HashCode)

  addr_similarity = fuzz.partial_token_set_ratio(str_CustFullAdrr_hashCode, str_searchFullAddr_HashCode)
  print('addr_similarity === ', addr_similarity)

  if (addr_similarity >= 90):
    print("New Customer's Address also Found Matching along with Customer's Name using 'fuzz.partial_token_set_ratio'")
    print('Matching Similarity === ', addr_similarity)
    print('\n This Customer we searched seems to be Already Existing! \n Please check further Critical Information before adding the Customer!')
  else:
    print('Address does not seem to be matching!')
else:
  print('Name Similarity < 90, Customer does not seem to be found in the dataset!')
# Out:
# Name Similarity < 90, Customer does not seem to be found in the dataset!
